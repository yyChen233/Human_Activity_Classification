# %%
#人类行为识别
#陈奕阳、田泽予

# %%
#导入所需要的数据包
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score,log_loss
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, StratifiedShuffleSplit, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler, PowerTransformer, MinMaxScaler
from sklearn.metrics import accuracy_score, f1_score, plot_confusion_matrix, classification_report, precision_score, recall_score
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from IPython.display import display
import copy
import time
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#模式映射
mode_map = ["transient","lying","sitting","standing","walking","running",
            "cycling","Nordic_walking","","watching_TV","computer_work","car driving",
           "acending_stairs","descending_stairs","","","vacuum_cleaning","ironing",
           "folding_laundry","house_cleaning","playing_soccer","","","","rope_jumping"]
#参数映射
cols = ['time_stamp','activity_id','heart_rate','hand_temperature','hand_3D_acceleration_16_x','hand_3D_acceleration_16_y',
  'hand_3D_acceleration_16_z','hand_3D_acceleration_6_x','hand_3D_acceleration_6_y','hand_3D_acceleration_6_z',
  'hand_3D_gyroscope_x','hand_3D_gyroscope_y','hand_3D_gyroscope_z','hand_3D_magnetometer_x','hand_3D_magnetometer_y',
  'hand_3D_magnetometer_z','hand_4D_orientation_x','hand_4D_orientation_y','hand_4D_orientation_z','hand_4D_orientation_w',
  'chest_temperature','chest_3D_acceleration_16_x','chest_3D_acceleration_16_y','chest_3D_acceleration_16_z',
  'chest_3D_acceleration_6_x','chest_3D_acceleration_6_y','chest_3D_acceleration_6_z','chest_3D_gyroscope_x','chest_3D_gyroscope_y',
  'chest_3D_gyroscope_z','chest_3D_magnetometer_x','chest_3D_magnetometer_y','chest_3D_magnetometer_z','chest_4D_orientation_x',
  'chest_4D_orientation_y','chest_4D_orientation_z','chest_4D_orientation_w','ankle_temperature','ankle_3D_acceleration_16_x',
  'ankle_3D_acceleration_16_y','ankle_3D_acceleration_16_z','ankle_3D_acceleration_6_x','ankle_3D_acceleration_6_y',
  'ankle_3D_acceleration_6_z','ankle_3D_gyroscope_x','ankle_3D_gyroscope_y','ankle_3D_gyroscope_z','ankle_3D_magnetometer_x',
  'ankle_3D_magnetometer_y','ankle_3D_magnetometer_z','ankle_4D_orientation_x','ankle_4D_orientation_y','ankle_4D_orientation_z',
  'ankle_4D_orientation_w']

# %%
#读入数据集--按subject
path = "./PAMAP2_Dataset/Protocol/subject"
def load_subjects(path):
    subjects = []
    
    for i in range(101,110):
        data_path = path + str(i) +'.dat'
        subject = pd.read_table(data_path, header=None, sep='\s+')
        subject.columns = cols 
        subject['id'] = i
        subjects.append(subject)

    return subjects

data_subject = load_subjects(path)

# %%
data_subject[1]
# Out:
#         time_stamp  activity_id  heart_rate  hand_temperature  \
# 0             5.64            0         NaN            33.000
# 1             5.65            0         NaN            33.000
# 2             5.66            0       100.0            33.000
# 3             5.67            0         NaN            33.000
# 4             5.68            0         NaN            33.000
# ...            ...          ...         ...               ...
# 446995     4475.59            0         NaN            29.125
# 446996     4475.60            0         NaN            29.125
# 446997     4475.61            0         NaN            29.125
# 446998     4475.62            0         NaN            29.125
# 446999     4475.63            0       134.0            29.125
#
#         hand_3D_acceleration_16_x  hand_3D_acceleration_16_y  \
# 0                        2.791430                   7.553890
# 1                        2.860860                   7.438140
# 2                        2.809970                   7.094300
# 3                        2.771380                   6.980770
# 4                        2.767100                   7.131190
# ...                           ...                        ...
# 446995                  -0.040828                  -0.050765
# 446996                  -0.004109                  -0.013453
# 446997                  -0.073003                  -0.011192
# 446998                   0.189650                   0.099912
# 446999                  -0.033339                  -0.124631
#
#         hand_3D_acceleration_16_z  hand_3D_acceleration_6_x  \
# 0                        -7.06374                  2.875530
# 1                        -7.21626                  2.842480
# 2                        -7.52376                  2.793730
# 3                        -7.52396                  2.806270
# 4                        -7.67848                  2.787660
# ...                           ...                       ...
# 446995                    9.77696                 -0.007455
# 446996                    9.73890                 -0.067866
# 446997                    9.93029                 -0.067358
# 446998                    9.85688                 -0.067233
# 446999                   10.00820                 -0.052037
#
#         hand_3D_acceleration_6_y  hand_3D_acceleration_6_z  ...  \
# 0                       7.888230                  -6.76139  ...
# 1                       7.631640                  -6.85140  ...
# 2                       7.435450                  -7.07744  ...
# 3                       7.299290                  -7.24326  ...
# 4                       7.117970                  -7.48445  ...
# ...                          ...                       ...  ...
# 446995                  0.010854                   9.76395  ...
# 446996                 -0.018901                   9.77918  ...
# 446997                  0.041505                   9.77905  ...
# 446998                  0.026430                   9.80928  ...
# 446999                  0.026334                   9.82437  ...
#
#         ankle_3D_gyroscope_y  ankle_3D_gyroscope_z  ankle_3D_magnetometer_x  \
# 0                  -0.031190             -0.040897                 -47.7695
# 1                  -0.036384             -0.014845                 -47.7624
# 2                  -0.034529             -0.040074                 -47.5393
# 3                  -0.011560              0.015434                 -47.4246
# 4                  -0.034663              0.007239                 -47.5412
# ...                      ...                   ...                      ...
# 446995             -0.003273             -0.002873                  23.2899
# 446996             -0.028774             -0.014796                  23.7429
# 446997              0.006235             -0.003494                  23.1758
# 446998              0.004279             -0.011373                  23.2890
# 446999              0.004652             -0.029530                  23.4168
#
#         ankle_3D_magnetometer_y  ankle_3D_magnetometer_z  \
# 0                      -2.58701                  59.8481
# 1                      -2.81438                  60.3407
# 2                      -2.38909                  60.9623
# 3                      -2.72082                  60.7103
# 4                      -2.60153                  60.3412
# ...                         ...                      ...
# 446995                 13.04520                 -52.9575
# 446996                 12.91400                 -52.5913
# 446997                 13.05240                 -53.2040
# 446998                 12.83110                 -53.4549
# 446999                 12.47780                 -52.0981
#
#         ankle_4D_orientation_x  ankle_4D_orientation_y  \
# 0                    -0.012871                0.747947
# 1                     0.014025               -0.748410
# 2                     0.012714               -0.749508
# 3                     0.012639               -0.749201
# 4                     0.012571               -0.749291
# ...                        ...                     ...
# 446995                0.963468                0.150467
# 446996                0.963511                0.150692
# 446997                0.963689                0.149824
# 446998                0.963846                0.148631
# 446999                0.963823                0.148712
#
#         ankle_4D_orientation_z  ankle_4D_orientation_w   id
# 0                    -0.079841                0.658813  102
# 1                     0.079043               -0.658360  102
# 2                     0.075286               -0.657577  102
# 3                     0.076030               -0.657843  102
# 4                     0.076346               -0.657705  102
# ...                        ...                     ...  ...
# 446995               -0.152542               -0.160685  102
# 446996               -0.152539               -0.160219  102
# 446997               -0.152549               -0.159953  102
# 446998               -0.152432               -0.160234  102
# 446999               -0.152398               -0.160328  102
#
# [447000 rows x 55 columns]

# %%
#处理缺失数据
data_subject[1].isna().sum()
# Out:
# time_stamp                         0
# activity_id                        0
# heart_rate                    406205
# hand_temperature                2729
# hand_3D_acceleration_16_x       2729
# hand_3D_acceleration_16_y       2729
# hand_3D_acceleration_16_z       2729
# hand_3D_acceleration_6_x        2729
# hand_3D_acceleration_6_y        2729
# hand_3D_acceleration_6_z        2729
# hand_3D_gyroscope_x             2729
# hand_3D_gyroscope_y             2729
# hand_3D_gyroscope_z             2729
# hand_3D_magnetometer_x          2729
# hand_3D_magnetometer_y          2729
# hand_3D_magnetometer_z          2729
# hand_4D_orientation_x           2729
# hand_4D_orientation_y           2729
# hand_4D_orientation_z           2729
# hand_4D_orientation_w           2729
# chest_temperature                387
# chest_3D_acceleration_16_x       387
# chest_3D_acceleration_16_y       387
# chest_3D_acceleration_16_z       387
# chest_3D_acceleration_6_x        387
# chest_3D_acceleration_6_y        387
# chest_3D_acceleration_6_z        387
# chest_3D_gyroscope_x             387
# chest_3D_gyroscope_y             387
# chest_3D_gyroscope_z             387
# chest_3D_magnetometer_x          387
# chest_3D_magnetometer_y          387
# chest_3D_magnetometer_z          387
# chest_4D_orientation_x           387
# chest_4D_orientation_y           387
# chest_4D_orientation_z           387
# chest_4D_orientation_w           387
# ankle_temperature               2445
# ankle_3D_acceleration_16_x      2445
# ankle_3D_acceleration_16_y      2445
# ankle_3D_acceleration_16_z      2445
# ankle_3D_acceleration_6_x       2445
# ankle_3D_acceleration_6_y       2445
# ankle_3D_acceleration_6_z       2445
# ankle_3D_gyroscope_x            2445
# ankle_3D_gyroscope_y            2445
# ankle_3D_gyroscope_z            2445
# ankle_3D_magnetometer_x         2445
# ankle_3D_magnetometer_y         2445
# ankle_3D_magnetometer_z         2445
# ankle_4D_orientation_x          2445
# ankle_4D_orientation_y          2445
# ankle_4D_orientation_z          2445
# ankle_4D_orientation_w          2445
# id                                 0
# dtype: int64

# %%
def fix_data(data):
    output = []
    for subject in data:
        subject = subject.interpolate()
        subject = subject.drop(subject[subject['activity_id']==0].index)
        output.append(subject)
    return output

data_subject = fix_data(data_subject)

# %%
def check_null(data):
    for idx, subject in enumerate(data):
        no_null_values = subject.isnull().sum().sum()
        print(f'Subject 10{idx + 1}: {no_null_values} null value')
        
check_null(data_subject)
# Out:
# Subject 101: 0 null value
# Subject 102: 0 null value
# Subject 103: 0 null value
# Subject 104: 0 null value
# Subject 105: 0 null value
# Subject 106: 0 null value
# Subject 107: 0 null value
# Subject 108: 0 null value
# Subject 109: 0 null value

# %%
data_subject[1]
# Out:
#         time_stamp  activity_id  heart_rate  hand_temperature  \
# 4956         55.20            1        96.0           33.4375
# 4957         55.21            1        96.0           33.4375
# 4958         55.22            1        96.0           33.4375
# 4959         55.23            1        96.0           33.4375
# 4960         55.24            1        96.0           33.4375
# ...            ...          ...         ...               ...
# 424000     4245.64           24       177.0           28.5625
# 424001     4245.65           24       177.0           28.5625
# 424002     4245.66           24       177.0           28.5625
# 424003     4245.67           24       177.0           28.5625
# 424004     4245.68           24       177.0           28.5625
#
#         hand_3D_acceleration_16_x  hand_3D_acceleration_16_y  \
# 4956                     -6.88206                    6.54265
# 4957                     -6.84775                    6.61723
# 4958                     -6.96887                    6.46467
# 4959                     -6.85123                    6.50274
# 4960                     -6.80836                    6.46585
# ...                           ...                        ...
# 424000                    6.89559                    6.13782
# 424001                    6.80903                    6.47650
# 424002                    6.51286                    7.16208
# 424003                    6.31694                    8.07073
# 424004                    6.27032                    8.33391
#
#         hand_3D_acceleration_16_z  hand_3D_acceleration_6_x  \
# 4956                     2.839970                  -6.73279
# 4957                     2.724770                  -6.76319
# 4958                     2.531040                  -6.73368
# 4959                     2.648130                  -6.77876
# 4960                     2.802850                  -6.73342
# ...                           ...                       ...
# 424000                  -0.608584                   6.65593
# 424001                  -0.995897                   6.77081
# 424002                  -0.964159                   6.63710
# 424003                  -1.355030                   6.33989
# 424004                  -1.664520                   6.13275
#
#         hand_3D_acceleration_6_y  hand_3D_acceleration_6_z  ...  \
# 4956                     6.51666                  2.764920  ...
# 4957                     6.44141                  2.810420  ...
# 4958                     6.41095                  2.765150  ...
# 4959                     6.44146                  2.750030  ...
# 4960                     6.48641                  2.719690  ...
# ...                          ...                       ...  ...
# 424000                   6.59835                 -0.329509  ...
# 424001                   6.29512                 -0.706482  ...
# 424002                   6.70368                 -0.888449  ...
# 424003                   7.33999                 -1.025450  ...
# 424004                   8.18685                 -1.419710  ...
#
#         ankle_3D_gyroscope_y  ankle_3D_gyroscope_z  ankle_3D_magnetometer_x  \
# 4956               -0.066935              0.030631                 -47.1271
# 4957               -0.012545              0.028780                 -46.6862
# 4958               -0.033412              0.025411                 -46.9033
# 4959               -0.052608              0.037883                 -46.4507
# 4960               -0.029521              0.035770                 -46.5720
# ...                      ...                   ...                      ...
# 424000             -0.045599              0.065027                 -36.0814
# 424001             -0.038047              0.076966                 -36.1900
# 424002             -0.005824              0.059216                 -35.9658
# 424003             -0.012182              0.076491                 -36.1976
# 424004              0.029264              0.072089                 -36.5314
#
#         ankle_3D_magnetometer_y  ankle_3D_magnetometer_z  \
# 4956                   0.458018                  61.4844
# 4957                   0.562565                  60.7392
# 4958                   0.343084                  61.2338
# 4959                   0.104924                  61.3513
# 4960                   0.339549                  60.6122
# ...                         ...                      ...
# 424000                 5.587010                  36.0741
# 424001                 5.477260                  36.3214
# 424002                 5.469380                  36.3195
# 424003                 5.813340                  35.9537
# 424004                 5.713140                  36.0792
#
#         ankle_4D_orientation_x  ankle_4D_orientation_y  \
# 4956                  0.007827                0.758203
# 4957                  0.008081                0.758213
# 4958                  0.008235                0.758292
# 4959                  0.008450                0.758427
# 4960                  0.008722                0.758488
# ...                        ...                     ...
# 424000                0.050121                0.770539
# 424001                0.049857                0.770637
# 424002                0.049647                0.770630
# 424003                0.049668                0.770648
# 424004                0.049491                0.770534
#
#         ankle_4D_orientation_z  ankle_4D_orientation_w   id
# 4956                 -0.085761                0.646307  102
# 4957                 -0.085730                0.646295  102
# 4958                 -0.085732                0.646201  102
# 4959                 -0.085745                0.646038  102
# 4960                 -0.085689                0.645970  102
# ...                        ...                     ...  ...
# 424000               -0.048775                0.633545  102
# 424001               -0.049465                0.633392  102
# 424002               -0.050004                0.633375  102
# 424003               -0.050575                0.633307  102
# 424004               -0.051183                0.633410  102
#
# [263349 rows x 55 columns]

# %%
data = pd.concat(data_subject).reset_index(drop=True)
data
# Out:
#          time_stamp  activity_id  heart_rate  hand_temperature  \
# 0             37.66            1       100.0            30.375
# 1             37.67            1       100.0            30.375
# 2             37.68            1       100.0            30.375
# 3             37.69            1       100.0            30.375
# 4             37.70            1       100.0            30.375
# ...             ...          ...         ...               ...
# 1942867       95.06           24       162.0            25.125
# 1942868       95.07           24       162.0            25.125
# 1942869       95.08           24       162.0            25.125
# 1942870       95.09           24       162.0            25.125
# 1942871       95.10           24       162.0            25.125
#
#          hand_3D_acceleration_16_x  hand_3D_acceleration_16_y  \
# 0                          2.21530                    8.27915
# 1                          2.29196                    7.67288
# 2                          2.29090                    7.14240
# 3                          2.21800                    7.14365
# 4                          2.30106                    7.25857
# ...                            ...                        ...
# 1942867                    4.99466                    6.01881
# 1942868                    5.02764                    5.90369
# 1942869                    5.06409                    5.71370
# 1942870                    5.13914                    5.63724
# 1942871                    5.00812                    5.40645
#
#          hand_3D_acceleration_16_z  hand_3D_acceleration_6_x  \
# 0                          5.58753                   2.24689
# 1                          5.74467                   2.27373
# 2                          5.82342                   2.26966
# 3                          5.89930                   2.22177
# 4                          6.09259                   2.20720
# ...                            ...                       ...
# 1942867                    5.59830                   4.90787
# 1942868                    5.48372                   4.89090
# 1942869                    5.48491                   4.97981
# 1942870                    5.48629                   4.97690
# 1942871                    5.02326                   4.97362
#
#          hand_3D_acceleration_6_y  hand_3D_acceleration_6_z  ...  \
# 0                         8.55387                   5.77143  ...
# 1                         8.14592                   5.78739  ...
# 2                         7.66268                   5.78846  ...
# 3                         7.25535                   5.88000  ...
# 4                         7.24042                   5.95555  ...
# ...                           ...                       ...  ...
# 1942867                   6.05780                   5.68357  ...
# 1942868                   5.95209                   5.56301  ...
# 1942869                   5.87584                   5.45738  ...
# 1942870                   5.69448                   5.29167  ...
# 1942871                   5.45272                   5.14120  ...
#
#          ankle_3D_gyroscope_y  ankle_3D_gyroscope_z  ankle_3D_magnetometer_x  \
# 0                   -0.027714              0.001752                 -61.1081
# 1                    0.000945              0.006007                 -60.8916
# 2                   -0.052422             -0.004882                 -60.3407
# 3                   -0.018844              0.026950                 -60.7646
# 4                   -0.048878             -0.006328                 -60.2040
# ...                       ...                   ...                      ...
# 1942867             -0.012885              0.005878                 -45.7855
# 1942868              0.003629             -0.004235                 -46.0331
# 1942869             -0.035176             -0.002309                 -45.5140
# 1942870             -0.036457             -0.007076                 -45.9093
# 1942871             -0.030195              0.018229                 -46.1702
#
#          ankle_3D_magnetometer_y  ankle_3D_magnetometer_z  \
# 0                     -36.863600               -58.369600
# 1                     -36.319700               -58.365600
# 2                     -35.784200               -58.611900
# 3                     -37.102800               -57.879900
# 4                     -37.122500               -57.884700
# ...                          ...                      ...
# 1942867                -0.831734                -0.170139
# 1942868                -0.817288                 0.538134
# 1942869                -1.229410                 0.540438
# 1942870                -0.565555                 0.680109
# 1942871                -0.812965                -0.313346
#
#          ankle_4D_orientation_x  ankle_4D_orientation_y  \
# 0                      1.000000                0.000000
# 1                      1.000000                0.000000
# 2                      1.000000                0.000000
# 3                      1.000000                0.000000
# 4                      1.000000                0.000000
# ...                         ...                     ...
# 1942867                0.522929               -0.291612
# 1942868                0.522880               -0.291694
# 1942869                0.522625               -0.291978
# 1942870                0.522536               -0.291955
# 1942871                0.522730               -0.291275
#
#          ankle_4D_orientation_z  ankle_4D_orientation_w   id
# 0                      0.000000                0.000000  101
# 1                      0.000000                0.000000  101
# 2                      0.000000                0.000000  101
# 3                      0.000000                0.000000  101
# 4                      0.000000                0.000000  101
# ...                         ...                     ...  ...
# 1942867                0.705786               -0.378648  109
# 1942868                0.705895               -0.378450  109
# 1942869                0.706161               -0.378084  109
# 1942870                0.706426               -0.377733  109
# 1942871                0.706526               -0.377800  109
#
# [1942872 rows x 55 columns]

# %%
'''
ss = StratifiedShuffleSplit(n_splits = 1, test_size = 0.25,random_state=42)
def split_train_test(data, scaler):
    X = data.drop(['id','activity_id'], axis = 1).to_numpy()
    y = data['activity_id'].to_numpy()
    for train_index, test_index in ss.split(X, y):
    #print("TRAIN_INDEX:", train_index, "TEST_INDEX:", test_index)#获得索引值
        X_train, X_test = X[train_index], X[test_index]#训练集对应的值
        y_train, y_test = y[train_index], y[test_index]#类别集对应的值
    
    if scaler == 'StandardScaler':
        scaler = StandardScaler()
        scaler.fit(X_train)
        scaler.fit(X_test)
        X_train = scaler.transform(X_train)
        X_test = scaler.transform(X_test)
    if scaler == 'MinMaxScaler':
        scaler = MinMaxScaler()
        scaler.fit(X_train)
        scaler.fit(X_test)
        X_train = scaler.transform(X_train)
        X_test = scaler.transform(X_test)
    elif scaler == 'PowerTransformer':
        scaler = PowerTransformer()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.fit_transform(X_test)
    
    return X_train, X_test, y_train, y_test
'''
def split_train_test(data, scaler):
    subject107 = data[data['id'] == 107]
    subject108 = data[data['id'] == 108]
    test = subject107.append(subject108)
    
    train = data[data['id'] != 107]
    train = train[train['id'] != 108]
    
    test = test.drop(['id'], axis = 1)
    train = train.drop(['id'], axis = 1)
    
    X_train = train.drop(['activity_id'], axis = 1)
    X_test = test.drop(['activity_id'], axis = 1)
    
    if scaler == 'StandardScaler':
        scaler = StandardScaler()
        scaler.fit(X_train)
        scaler.fit(X_test)
        X_train = scaler.transform(X_train)
        X_test = scaler.transform(X_test)
    if scaler == 'MinMaxScaler':
        scaler = MinMaxScaler()
        scaler.fit(X_train)
        scaler.fit(X_test)
        X_train = scaler.transform(X_train)
        X_test = scaler.transform(X_test)
    elif scaler == 'PowerTransformer':
        scaler = PowerTransformer()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.fit_transform(X_test)
    elif scaler == 'none':
        X_train = X_train.values
        X_test = X_test.values
    y_train = train['activity_id'].values
    y_test = test['activity_id'].values
    return X_train, X_test, y_train, y_test

# %%
N_FFT_PEAKS = 5

subject = data_subject[0]
columns=['activity_id']
new_feats = ['max', 'min', 'mean', 'var', 'skew', 'kurtosis']
#new_feats = ['mean']
#fft_feats = [f'top{i}_{k}' for k in ['PSD', 'freq'] for i in range(1, N_FFT_PEAKS+1)]
#new_feats += fft_feats
new_cols = [f'{feat}_{col}' for col in subject.columns[2:-1] for feat in new_feats]
columns += new_cols + ['id']

# %%
#分段
def moving_window(df, length=512, shift=100):
    size = df.shape[0]
    prev = 0
    for start in range(0, size, length-shift):
        yield df[start:start + length] if start + length < size else df[start:size]

# %%
rows = []
for subject in data_subject:
    for segment in moving_window(subject,length=512,shift=0):
        row = []
        row.append(segment['activity_id'].mode()[0])
        t = segment['time_stamp']
        for i in range(2, len(segment.columns)-1):
            series = segment.iloc[:, i]
            row.append(series.max())
            row.append(series.min())
            row.append(series.mean())
            row.append(series.var())
            row.append(series.skew())
            row.append(series.kurtosis())
        row.append(segment['id'].iloc[0])
        rows.append(row)
segmented = pd.DataFrame(rows, columns=columns)
segmented
# Out:
#       activity_id  max_heart_rate  min_heart_rate  mean_heart_rate  \
# 0               1      102.000000           100.0       101.490234
# 1               1      103.000000           102.0       102.207031
# 2               1      105.909091           103.0       104.054688
# 3               1      107.000000           106.0       106.705078
# 4               1      106.000000           103.0       104.560547
# ...           ...             ...             ...              ...
# 3794           24      154.000000           153.0       153.171875
# 3795           24      154.000000           153.0       153.050781
# 3796           24      159.000000           154.0       156.237305
# 3797           24      161.000000           159.0       160.111328
# 3798           24      162.000000           161.0       161.380567
#
#       var_heart_rate  skew_heart_rate  kurtosis_heart_rate  \
# 0           0.411575        -0.882699            -0.326263
# 1           0.160932         1.450112             0.130486
# 2           0.675175        -0.024326            -1.385904
# 3           0.201234        -0.901677            -1.157321
# 4           0.827140        -0.047368            -0.822068
# ...              ...              ...                  ...
# 3794        0.135496         1.742804             1.115500
# 3795        0.044739         4.094710            15.151994
# 3796        2.008618         0.378598            -1.044418
# 3797        0.639957        -0.203103            -1.423994
# 3798        0.229303         0.494795            -1.741654
#
#       max_hand_temperature  min_hand_temperature  mean_hand_temperature  ...  \
# 0                  30.4375               30.3750              30.417480  ...
# 1                  30.5000               30.4375              30.486084  ...
# 2                  30.5625               30.5000              30.526611  ...
# 3                  30.6250               30.5625              30.573975  ...
# 4                  30.6250               30.6250              30.625000  ...
# ...                    ...                   ...                    ...  ...
# 3794               25.1250               25.0625              25.119385  ...
# 3795               25.1250               25.1250              25.125000  ...
# 3796               25.1250               25.1250              25.125000  ...
# 3797               25.1250               25.1250              25.125000  ...
# 3798               25.1875               25.1250              25.139676  ...
#
#       var_ankle_4D_orientation_z  skew_ankle_4D_orientation_z  \
# 0                       0.000000                     0.000000
# 1                       0.000000                     0.000000
# 2                       0.000000                     0.000000
# 3                       0.000000                     0.000000
# 4                       0.000000                     0.000000
# ...                          ...                          ...
# 3794                    0.001545                    -0.669159
# 3795                    0.001359                    -0.374331
# 3796                    0.003328                    -0.297803
# 3797                    0.003067                    -0.656631
# 3798                    0.004182                    -0.674410
#
#       kurtosis_ankle_4D_orientation_z  max_ankle_4D_orientation_w  \
# 0                            0.000000                    0.000000
# 1                            0.000000                    0.000000
# 2                            0.000000                    0.000000
# 3                            0.000000                    0.000000
# 4                            0.000000                    0.000000
# ...                               ...                         ...
# 3794                         0.359304                   -0.070364
# 3795                        -0.397474                   -0.196159
# 3796                         0.132597                   -0.159602
# 3797                        -0.174480                   -0.009793
# 3798                        -1.315069                   -0.331905
#
#       min_ankle_4D_orientation_w  mean_ankle_4D_orientation_w  \
# 0                       0.000000                     0.000000
# 1                       0.000000                     0.000000
# 2                       0.000000                     0.000000
# 3                       0.000000                     0.000000
# 4                       0.000000                     0.000000
# ...                          ...                          ...
# 3794                   -0.441434                    -0.297615
# 3795                   -0.484406                    -0.352572
# 3796                   -0.551772                    -0.379662
# 3797                   -0.405541                    -0.246068
# 3798                   -0.513716                    -0.407458
#
#       var_ankle_4D_orientation_w  skew_ankle_4D_orientation_w  \
# 0                       0.000000                     0.000000
# 1                       0.000000                     0.000000
# 2                       0.000000                     0.000000
# 3                       0.000000                     0.000000
# 4                       0.000000                     0.000000
# ...                          ...                          ...
# 3794                    0.007945                     0.496857
# 3795                    0.004334                     0.296299
# 3796                    0.007334                     0.526879
# 3797                    0.011363                     0.356198
# 3798                    0.001703                    -1.000507
#
#       kurtosis_ankle_4D_orientation_w   id
# 0                            0.000000  101
# 1                            0.000000  101
# 2                            0.000000  101
# 3                            0.000000  101
# 4                            0.000000  101
# ...                               ...  ...
# 3794                        -0.658364  109
# 3795                        -0.784905  109
# 3796                        -0.368876  109
# 3797                        -1.025469  109
# 3798                         0.224318  109
#
# [3799 rows x 314 columns]

# %%
#交叉验证方式
CV_TYPES = ['Stratified Random Sampling', 'K-Fold']
result_info = {'Model': [], 
               'Validation Accuracy': [],
               'Accuracy': [],
               'Precision': [], 
               'Recall': [], 
               'F1-score': [], 
               'Best Hyper-paramerters': [], 
               'Training Time': [],
               'Cross-validation': []}

# %%
def get_dict_score(model, grid, cv_type, scaler):
    score_array = []
    best_score = [0,0]
    start_time = time.time()
    
    if cv_type == 'Stratified Random Sampling':
        for params in grid:
            print("Stratified Random Sampling - Running on params: ", params)
            sss = StratifiedShuffleSplit(n_splits = 10, test_size = 0.25, random_state = 42)
            accuracy_sss = []
            for train_index, test_index in sss.split(X_train, y_train):
                X_train_sss, X_test_sss = X_train[train_index], X_train[test_index]
                y_train_sss, y_valid_sss = y_train[train_index], y_train[test_index]
                sss_model = model.set_params(**params)
                sss_model.fit(X_train_sss, y_train_sss)
                # evaluate model
                preds_sss = sss_model.predict(X_test_sss)
                # store accuracy
                accuracy_sss.append(accuracy_score(preds_sss, y_valid_sss))
            score_dict = {}
            score_dict['params'] = params
            score_dict['mean'] = np.mean(accuracy_sss)
            score_dict['std'] = np.std(accuracy_sss)
            score_array.append(score_dict)
            if score_dict['mean'] >= best_score[0]:
                best_score[0] = score_dict['mean']
                best_score[1] = score_dict['std']
            
    elif cv_type == 'K-Fold':
        p_fold_cv = KFold(n_splits=10, shuffle=True, random_state=42)
        for params in grid:
            print("KFold - Running on params: ", params)
            p_fold_model = model.set_params(**params)
            scores = cross_val_score(p_fold_model, X_train, y_train, scoring='accuracy', cv=p_fold_cv, n_jobs=-1)
            score_dict = {}
            score_dict['params'] = params
            score_dict['mean'] = scores.mean()
            score_dict['std'] = scores.std()
            score_array.append(score_dict)
            if score_dict['mean'] >= best_score[0]:
                best_score[0] = score_dict['mean']
                best_score[1] = score_dict['std']
    
    executed_time = time.time() - start_time
    return score_array, executed_time, best_score

# %%
def get_best_param(cv_score):
    best_score = 0
    best_param = {}
    for params in cv_score:
        if params['mean'] > best_score:
            best_score = params['mean']
            best_param = params
    return best_param['params']

# %%
def performance_info(model, best_params):
    opt_model = model.set_params(**best_params)
    opt_model.fit(X_train, y_train)
    pred_test = opt_model.predict(X_test)
    np.savetxt("pred_test.csv",pred_test, delimiter=",")
    result_info['Model'].append(type(model).__name__)
    result_info['Validation Accuracy'].append(str(best_score[0].round(6)*100) + ' +- ' + str(best_score[1].round(6)*100))
    result_info['Accuracy'].append(accuracy_score(y_test, pred_test).round(6)*100)
    result_info['Precision'].append(precision_score(y_test, pred_test, average = 'macro').round(6)*100)
    result_info['Recall'].append(recall_score(y_test, pred_test, average = 'macro').round(6)*100)
    result_info['F1-score'].append(f1_score(y_test, pred_test, average = 'macro').round(6)*100)
    result_info['Best Hyper-paramerters'].append(get_best_param(score))
    result_info['Training Time'].append(str(training_time) + 's')
    result_info['Cross-validation'].append(cv_type)

# %%
#逻辑回归
lr_grid_1 = [{'penalty':'none'}]
lr_grid = [{'C':0.001},{'C':0.01},{'C':0.1},{'C':1},{'C':10},{'C':100},{'C':1000}]

# %%
X_train, X_test, y_train, y_test = split_train_test(segmented, scaler='none')
np.savetxt("ytest.csv",y_test, delimiter=",")
for cv_type in CV_TYPES:
    lr = LogisticRegression(max_iter = 100, multi_class='multinomial')
    score, training_time, best_score = get_dict_score(lr, lr_grid_1, cv_type, scaler='none')
    best_params = get_best_param(score)
    performance_info(lr, best_params)
# Out:
# Stratified Random Sampling - Running on params:  {'penalty': 'none'}
# KFold - Running on params:  {'penalty': 'none'}

# %%
#k-NN
knn_grid = []
for i in range(2,20):
    knn_grid.append({'metric':'euclidean','n_neighbors':i})
for i in range(2,20):
    knn_grid.append({'metric':'manhattan','n_neighbors':i})
knn_grid
# Out:
# [{'metric': 'euclidean', 'n_neighbors': 2},
#  {'metric': 'euclidean', 'n_neighbors': 3},
#  {'metric': 'euclidean', 'n_neighbors': 4},
#  {'metric': 'euclidean', 'n_neighbors': 5},
#  {'metric': 'euclidean', 'n_neighbors': 6},
#  {'metric': 'euclidean', 'n_neighbors': 7},
#  {'metric': 'euclidean', 'n_neighbors': 8},
#  {'metric': 'euclidean', 'n_neighbors': 9},
#  {'metric': 'euclidean', 'n_neighbors': 10},
#  {'metric': 'euclidean', 'n_neighbors': 11},
#  {'metric': 'euclidean', 'n_neighbors': 12},
#  {'metric': 'euclidean', 'n_neighbors': 13},
#  {'metric': 'euclidean', 'n_neighbors': 14},
#  {'metric': 'euclidean', 'n_neighbors': 15},
#  {'metric': 'euclidean', 'n_neighbors': 16},
#  {'metric': 'euclidean', 'n_neighbors': 17},
#  {'metric': 'euclidean', 'n_neighbors': 18},
#  {'metric': 'euclidean', 'n_neighbors': 19},
#  {'metric': 'manhattan', 'n_neighbors': 2},
#  {'metric': 'manhattan', 'n_neighbors': 3},
#  {'metric': 'manhattan', 'n_neighbors': 4},
#  {'metric': 'manhattan', 'n_neighbors': 5},
#  {'metric': 'manhattan', 'n_neighbors': 6},
#  {'metric': 'manhattan', 'n_neighbors': 7},
#  {'metric': 'manhattan', 'n_neighbors': 8},
#  {'metric': 'manhattan', 'n_neighbors': 9},
#  {'metric': 'manhattan', 'n_neighbors': 10},
#  {'metric': 'manhattan', 'n_neighbors': 11},
#  {'metric': 'manhattan', 'n_neighbors': 12},
#  {'metric': 'manhattan', 'n_neighbors': 13},
#  {'metric': 'manhattan', 'n_neighbors': 14},
#  {'metric': 'manhattan', 'n_neighbors': 15},
#  {'metric': 'manhattan', 'n_neighbors': 16},
#  {'metric': 'manhattan', 'n_neighbors': 17},
#  {'metric': 'manhattan', 'n_neighbors': 18},
#  {'metric': 'manhattan', 'n_neighbors': 19}]

# %%
X_train, X_test, y_train, y_test = split_train_test(segmented, scaler='none')
np.savetxt("ytest.csv",y_test, delimiter=",")
for cv_type in CV_TYPES:
    knn = KNeighborsClassifier()
    score, training_time, best_score = get_dict_score(knn, knn_grid, cv_type, scaler='none')
    knn_best_params = get_best_param(score)
    performance_info(knn, knn_best_params)
# Out:
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 2}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 3}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 4}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 5}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 6}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 7}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 8}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 9}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 10}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 11}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 12}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 13}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 14}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 15}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 16}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 17}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 18}
# Stratified Random Sampling - Running on params:  {'metric': 'euclidean', 'n_neighbors': 19}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 2}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 3}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 4}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 5}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 6}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 7}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 8}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 9}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 10}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 11}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 12}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 13}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 14}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 15}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 16}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 17}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 18}
# Stratified Random Sampling - Running on params:  {'metric': 'manhattan', 'n_neighbors': 19}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 2}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 3}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 4}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 5}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 6}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 7}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 8}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 9}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 10}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 11}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 12}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 13}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 14}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 15}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 16}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 17}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 18}
# KFold - Running on params:  {'metric': 'euclidean', 'n_neighbors': 19}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 2}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 3}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 4}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 5}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 6}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 7}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 8}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 9}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 10}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 11}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 12}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 13}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 14}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 15}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 16}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 17}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 18}
# KFold - Running on params:  {'metric': 'manhattan', 'n_neighbors': 19}

# %%
#随机森林
rf_grid = []
for i in list([10,20,30]):
    for j in list([50,120,200]):
        rf_grid.append({'max_depth':i, 'n_estimators':j})
rf_grid
# Out:
# [{'max_depth': 10, 'n_estimators': 50},
#  {'max_depth': 10, 'n_estimators': 120},
#  {'max_depth': 10, 'n_estimators': 200},
#  {'max_depth': 20, 'n_estimators': 50},
#  {'max_depth': 20, 'n_estimators': 120},
#  {'max_depth': 20, 'n_estimators': 200},
#  {'max_depth': 30, 'n_estimators': 50},
#  {'max_depth': 30, 'n_estimators': 120},
#  {'max_depth': 30, 'n_estimators': 200}]

# %%
X_train, X_test, y_train, y_test = split_train_test(segmented, scaler='none')
for cv_type in CV_TYPES:
    rf = RandomForestClassifier(random_state = 42)
    score, training_time, best_score = get_dict_score(rf, rf_grid, cv_type, scaler='none')
    best_params = get_best_param(score)
    performance_info(rf, best_params)
# Out:
# Stratified Random Sampling - Running on params:  {'max_depth': 10, 'n_estimators': 50}
# Stratified Random Sampling - Running on params:  {'max_depth': 10, 'n_estimators': 120}
# Stratified Random Sampling - Running on params:  {'max_depth': 10, 'n_estimators': 200}
# Stratified Random Sampling - Running on params:  {'max_depth': 20, 'n_estimators': 50}
# Stratified Random Sampling - Running on params:  {'max_depth': 20, 'n_estimators': 120}
# Stratified Random Sampling - Running on params:  {'max_depth': 20, 'n_estimators': 200}
# Stratified Random Sampling - Running on params:  {'max_depth': 30, 'n_estimators': 50}
# Stratified Random Sampling - Running on params:  {'max_depth': 30, 'n_estimators': 120}
# Stratified Random Sampling - Running on params:  {'max_depth': 30, 'n_estimators': 200}
# KFold - Running on params:  {'max_depth': 10, 'n_estimators': 50}
# KFold - Running on params:  {'max_depth': 10, 'n_estimators': 120}
# KFold - Running on params:  {'max_depth': 10, 'n_estimators': 200}
# KFold - Running on params:  {'max_depth': 20, 'n_estimators': 50}
# KFold - Running on params:  {'max_depth': 20, 'n_estimators': 120}
# KFold - Running on params:  {'max_depth': 20, 'n_estimators': 200}
# KFold - Running on params:  {'max_depth': 30, 'n_estimators': 50}
# KFold - Running on params:  {'max_depth': 30, 'n_estimators': 120}
# KFold - Running on params:  {'max_depth': 30, 'n_estimators': 200}

# %%
#Adaboost
ada_grid = []
for i in list(['gini','entropy']):
    for j in list([5,10,25,50,75]):
        ada_grid.append({'base_estimator__criterion':i, 'n_estimators':j})
ada_grid
# Out:
# [{'base_estimator__criterion': 'gini', 'n_estimators': 5},
#  {'base_estimator__criterion': 'gini', 'n_estimators': 10},
#  {'base_estimator__criterion': 'gini', 'n_estimators': 25},
#  {'base_estimator__criterion': 'gini', 'n_estimators': 50},
#  {'base_estimator__criterion': 'gini', 'n_estimators': 75},
#  {'base_estimator__criterion': 'entropy', 'n_estimators': 5},
#  {'base_estimator__criterion': 'entropy', 'n_estimators': 10},
#  {'base_estimator__criterion': 'entropy', 'n_estimators': 25},
#  {'base_estimator__criterion': 'entropy', 'n_estimators': 50},
#  {'base_estimator__criterion': 'entropy', 'n_estimators': 75}]

# %%
for cv_type in CV_TYPES:
    dtc = DecisionTreeClassifier(random_state = 42)
    ada = AdaBoostClassifier(base_estimator = dtc)
    score, training_time, best_score = get_dict_score(ada, ada_grid, cv_type, scaler='StandardScaler')
    best_params = get_best_param(score)
    performance_info(ada, best_params)
# Out:
# Stratified Random Sampling - Running on params:  {'base_estimator__criterion': 'gini', 'n_estimators': 5}
# Stratified Random Sampling - Running on params:  {'base_estimator__criterion': 'gini', 'n_estimators': 10}
# Stratified Random Sampling - Running on params:  {'base_estimator__criterion': 'gini', 'n_estimators': 25}
# Stratified Random Sampling - Running on params:  {'base_estimator__criterion': 'gini', 'n_estimators': 50}
# Stratified Random Sampling - Running on params:  {'base_estimator__criterion': 'gini', 'n_estimators': 75}
# Stratified Random Sampling - Running on params:  {'base_estimator__criterion': 'entropy', 'n_estimators': 5}
# Stratified Random Sampling - Running on params:  {'base_estimator__criterion': 'entropy', 'n_estimators': 10}
# Stratified Random Sampling - Running on params:  {'base_estimator__criterion': 'entropy', 'n_estimators': 25}
# Stratified Random Sampling - Running on params:  {'base_estimator__criterion': 'entropy', 'n_estimators': 50}
# Stratified Random Sampling - Running on params:  {'base_estimator__criterion': 'entropy', 'n_estimators': 75}
# KFold - Running on params:  {'base_estimator__criterion': 'gini', 'n_estimators': 5}
# KFold - Running on params:  {'base_estimator__criterion': 'gini', 'n_estimators': 10}
# KFold - Running on params:  {'base_estimator__criterion': 'gini', 'n_estimators': 25}
# KFold - Running on params:  {'base_estimator__criterion': 'gini', 'n_estimators': 50}
# KFold - Running on params:  {'base_estimator__criterion': 'gini', 'n_estimators': 75}
# KFold - Running on params:  {'base_estimator__criterion': 'entropy', 'n_estimators': 5}
# KFold - Running on params:  {'base_estimator__criterion': 'entropy', 'n_estimators': 10}
# KFold - Running on params:  {'base_estimator__criterion': 'entropy', 'n_estimators': 25}
# KFold - Running on params:  {'base_estimator__criterion': 'entropy', 'n_estimators': 50}
# KFold - Running on params:  {'base_estimator__criterion': 'entropy', 'n_estimators': 75}

# %%
#SVM
SVM_grid = []
for c in list([0.01,0.1,1,10,100]):
    for m in list(['linear','rbf','poly','sigmoid']):
        SVM_grid.append({'C':c, 'kernel':m})
SVM_grid
# Out:
# [{'C': 0.01, 'kernel': 'linear'},
#  {'C': 0.01, 'kernel': 'rbf'},
#  {'C': 0.01, 'kernel': 'poly'},
#  {'C': 0.01, 'kernel': 'sigmoid'},
#  {'C': 0.1, 'kernel': 'linear'},
#  {'C': 0.1, 'kernel': 'rbf'},
#  {'C': 0.1, 'kernel': 'poly'},
#  {'C': 0.1, 'kernel': 'sigmoid'},
#  {'C': 1, 'kernel': 'linear'},
#  {'C': 1, 'kernel': 'rbf'},
#  {'C': 1, 'kernel': 'poly'},
#  {'C': 1, 'kernel': 'sigmoid'},
#  {'C': 10, 'kernel': 'linear'},
#  {'C': 10, 'kernel': 'rbf'},
#  {'C': 10, 'kernel': 'poly'},
#  {'C': 10, 'kernel': 'sigmoid'},
#  {'C': 100, 'kernel': 'linear'},
#  {'C': 100, 'kernel': 'rbf'},
#  {'C': 100, 'kernel': 'poly'},
#  {'C': 100, 'kernel': 'sigmoid'}]

# %%
from sklearn import svm
X_train, X_test, y_train, y_test = split_train_test(segmented, scaler='none')
for cv_type in CV_TYPES:
    SVM = svm.SVC(gamma = 'auto', decision_function_shape='ovr')
    score, training_time, best_score = get_dict_score(SVM, SVM_grid, cv_type, scaler='none')
    best_params = get_best_param(score)
    performance_info(SVM, best_params)
# Out:
# Stratified Random Sampling - Running on params:  {'C': 0.01, 'kernel': 'linear'}
# Stratified Random Sampling - Running on params:  {'C': 0.01, 'kernel': 'rbf'}
# Stratified Random Sampling - Running on params:  {'C': 0.01, 'kernel': 'poly'}
# Stratified Random Sampling - Running on params:  {'C': 0.01, 'kernel': 'sigmoid'}
# Stratified Random Sampling - Running on params:  {'C': 0.1, 'kernel': 'linear'}
# Stratified Random Sampling - Running on params:  {'C': 0.1, 'kernel': 'rbf'}
# Stratified Random Sampling - Running on params:  {'C': 0.1, 'kernel': 'poly'}
# Stratified Random Sampling - Running on params:  {'C': 0.1, 'kernel': 'sigmoid'}
# Stratified Random Sampling - Running on params:  {'C': 1, 'kernel': 'linear'}
# Stratified Random Sampling - Running on params:  {'C': 1, 'kernel': 'rbf'}
# Stratified Random Sampling - Running on params:  {'C': 1, 'kernel': 'poly'}
# Stratified Random Sampling - Running on params:  {'C': 1, 'kernel': 'sigmoid'}
# Stratified Random Sampling - Running on params:  {'C': 10, 'kernel': 'linear'}
# Stratified Random Sampling - Running on params:  {'C': 10, 'kernel': 'rbf'}
# Stratified Random Sampling - Running on params:  {'C': 10, 'kernel': 'poly'}
# Stratified Random Sampling - Running on params:  {'C': 10, 'kernel': 'sigmoid'}
# Stratified Random Sampling - Running on params:  {'C': 100, 'kernel': 'linear'}
# Stratified Random Sampling - Running on params:  {'C': 100, 'kernel': 'rbf'}
# Stratified Random Sampling - Running on params:  {'C': 100, 'kernel': 'poly'}
# Stratified Random Sampling - Running on params:  {'C': 100, 'kernel': 'sigmoid'}
# KFold - Running on params:  {'C': 0.01, 'kernel': 'linear'}
# KFold - Running on params:  {'C': 0.01, 'kernel': 'rbf'}
# KFold - Running on params:  {'C': 0.01, 'kernel': 'poly'}
# KFold - Running on params:  {'C': 0.01, 'kernel': 'sigmoid'}
# KFold - Running on params:  {'C': 0.1, 'kernel': 'linear'}
# KFold - Running on params:  {'C': 0.1, 'kernel': 'rbf'}
# KFold - Running on params:  {'C': 0.1, 'kernel': 'poly'}
# KFold - Running on params:  {'C': 0.1, 'kernel': 'sigmoid'}
# KFold - Running on params:  {'C': 1, 'kernel': 'linear'}
# KFold - Running on params:  {'C': 1, 'kernel': 'rbf'}
# KFold - Running on params:  {'C': 1, 'kernel': 'poly'}
# KFold - Running on params:  {'C': 1, 'kernel': 'sigmoid'}
# KFold - Running on params:  {'C': 10, 'kernel': 'linear'}
# KFold - Running on params:  {'C': 10, 'kernel': 'rbf'}
# KFold - Running on params:  {'C': 10, 'kernel': 'poly'}
# KFold - Running on params:  {'C': 10, 'kernel': 'sigmoid'}
# KFold - Running on params:  {'C': 100, 'kernel': 'linear'}
# KFold - Running on params:  {'C': 100, 'kernel': 'rbf'}
# KFold - Running on params:  {'C': 100, 'kernel': 'poly'}
# KFold - Running on params:  {'C': 100, 'kernel': 'sigmoid'}

# %%
pd.DataFrame(result_info).to_csv('result_raw_more.csv')
pd.DataFrame(result_info)
# Out:
#                     Model                      Validation Accuracy  Accuracy  \
# 0      LogisticRegression                        90.9605 +- 1.2394   72.2854
# 1      LogisticRegression               91.80810000000001 +- 1.646   72.2854
# 2    KNeighborsClassifier                        90.9322 +- 0.7279   87.2802
# 3    KNeighborsClassifier                        91.9496 +- 1.5281   87.2802
# 4  RandomForestClassifier                        94.4209 +- 0.7534   88.6246
# 5  RandomForestClassifier                        94.4558 +- 1.2857   90.1758
# 6      AdaBoostClassifier                        89.6045 +- 0.9542   57.8077
# 7      AdaBoostClassifier                        89.7616 +- 2.0126   49.4312
# 8                     SVC  90.87570000000001 +- 0.6838000000000001   71.3547
# 9                     SVC              91.49040000000001 +- 0.9767   71.3547
#
#    Precision   Recall  F1-score  \
# 0    78.5625  70.1778   69.2962
# 1    78.5625  70.1778   69.2962
# 2    89.0952  84.1129   85.7998
# 3    89.0952  84.1129   85.7998
# 4    91.6627  86.3168   87.4135
# 5    92.8888  88.7293   89.9813
# 6    58.2127  56.6560   53.2224
# 7    50.1196  50.6520   44.7573
# 8    77.9868  70.0906   70.7164
# 9    77.9868  70.0906   70.7164
#
#                               Best Hyper-paramerters        Training Time  \
# 0                                {'penalty': 'none'}    9.51655912399292s
# 1                                {'penalty': 'none'}  18.193633317947388s
# 2          {'metric': 'manhattan', 'n_neighbors': 3}  234.81932520866394s
# 3          {'metric': 'manhattan', 'n_neighbors': 3}   42.90939998626709s
# 4             {'max_depth': 20, 'n_estimators': 120}  408.28677344322205s
# 5             {'max_depth': 10, 'n_estimators': 120}  131.96620535850525s
# 6  {'base_estimator__criterion': 'entropy', 'n_es...  111.53394889831543s
# 7  {'base_estimator__criterion': 'entropy', 'n_es...   66.95229840278625s
# 8                    {'C': 0.01, 'kernel': 'linear'}   302.6623456478119s
# 9                    {'C': 0.01, 'kernel': 'linear'}   173.2111461162567s
#
#              Cross-validation
# 0  Stratified Random Sampling
# 1                      K-Fold
# 2  Stratified Random Sampling
# 3                      K-Fold
# 4  Stratified Random Sampling
# 5                      K-Fold
# 6  Stratified Random Sampling
# 7                      K-Fold
# 8  Stratified Random Sampling
# 9                      K-Fold
